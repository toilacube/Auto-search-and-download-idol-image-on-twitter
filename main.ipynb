# %%
import twint
import pandas as pd
import nest_asyncio
import wget
import tweepy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
file = pd.read_csv("Jisoo5.csv")
file
# Out:
#                      id      conversation_id  \
# 0   1540293662222868480  1540293662222868480
# 1   1539845700162203648  1539845700162203648
# 2   1538315783855648768  1538315783855648768
# 3   1537791974819827712  1537791974819827712
# 4   1536981582078148609  1536981582078148609
# 5   1536332362920783873  1536332362920783873
# 6   1536330724890005506  1536330724890005506
# 7   1532375113072799744  1532375113072799744
# 8   1532269734175072256  1532269734175072256
# 9   1530004261580738560  1530004261580738560
# 10  1529092857398808576  1529092857398808576
# 11  1528754883100278786  1528754883100278786
# 12  1528716221826207744  1528716221826207744
# 13  1528711190284849158  1528711190284849158
# 14  1528576063315808256  1528576063315808256
# 15  1524283147436888065  1524283147436888065
# 16  1520322225823535104  1520322225823535104
# 17  1515187937801031684  1515187937801031684
# 18  1506165473385222146  1506165473385222146
# 19  1503262265155649539  1503262265155649539
#
# ...

# %%
auth = tweepy.OAuth1UserHandler('f8NXSyRuIjl4iWikWfJK9PCjY','oVrx1t5D9EZQRgreMU8qFgBPxcQBwecU2ZxCqfmfgsQN8a2bWY',
	'1533732766218481665-yea51P2kieI8jEpgqGwhqGZo0IP0L7','n8C6ohMDcCZxAvRZpg39sKDBBCUnKG7NkVImRi7cq942u')

api = tweepy.API(auth)

# %%
for i in file['id']:
    print("https://twitter.com/twitter/statuses/" + str(i))
# Out:
# https://twitter.com/twitter/statuses/1540293662222868480
# https://twitter.com/twitter/statuses/1539845700162203648
# https://twitter.com/twitter/statuses/1538315783855648768
# https://twitter.com/twitter/statuses/1537791974819827712
# https://twitter.com/twitter/statuses/1536981582078148609
# https://twitter.com/twitter/statuses/1536332362920783873
# https://twitter.com/twitter/statuses/1536330724890005506
# https://twitter.com/twitter/statuses/1532375113072799744
# https://twitter.com/twitter/statuses/1532269734175072256
# https://twitter.com/twitter/statuses/1530004261580738560
# https://twitter.com/twitter/statuses/1529092857398808576
# https://twitter.com/twitter/statuses/1528754883100278786
# https://twitter.com/twitter/statuses/1528716221826207744
# https://twitter.com/twitter/statuses/1528711190284849158
# https://twitter.com/twitter/statuses/1528576063315808256
# https://twitter.com/twitter/statuses/1524283147436888065
# ...

# %%
image = set()
for i in file['id']:
    status = api.get_status(str(i))
    media = status.entities.get('media')
    if(media != None):
        image.add(str(media[0]['media_url']))
        print (media[0]['media_url'])
# Out:
# http://pbs.twimg.com/media/FWA47AXUEAIOiD0.jpg
# http://pbs.twimg.com/media/FV6hgJPUsAA9Ud-.jpg
# http://pbs.twimg.com/media/FVkuSR3WQAADymo.jpg
# http://pbs.twimg.com/media/FVdVmFNaAAEb0-Z.jpg
# http://pbs.twimg.com/media/FVR0mJEWUAA9Awz.jpg
# http://pbs.twimg.com/media/FVImI-gUUAUpn0I.jpg
# http://pbs.twimg.com/media/FVIkpV7XwAARjEP.jpg
# http://pbs.twimg.com/media/FUQXCCkaIAAAiMW.jpg
# http://pbs.twimg.com/media/FUO3M18XEAMOVgi.jpg
# http://pbs.twimg.com/media/FThtfLeX0AEeO4V.jpg
# http://pbs.twimg.com/media/FTc6doNWIAEzxzs.jpg
# http://pbs.twimg.com/media/FSdXb3RXMAEi25O.jpg
# http://pbs.twimg.com/media/FRlFAPNXoAElURy.jpg
# http://pbs.twimg.com/media/FQcHZP6XwAQ7aCH.jpg
# http://pbs.twimg.com/media/FOb5gx2VgAU2-NL.jpg

# %%
for i in image:
    wget.download(i, "D:\jisoo_image")
# Out:
# 100% [............................................................................] 275503 / 275503
